# %%
# %cd drive/My Drive
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content

# %%
# %cd ..
# %cd darknet
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/darknet

# %%
import  os, sys
os.symlink('/content/drive/My Drive/ts', '/content/ts')
sys.path.insert(0, 'content/MyDrive')

# %%
# !./darknet detector train cfg/ts_data.data yolov4-tiny_train.cfg yolov4-tiny.conv.29 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#  1169: 0.050115, 0.063558 avg loss, 0.002610 rate, 0.639157 seconds, 74816 images, 0.296383 hours left
# Loaded: 0.493426 seconds - performance bottleneck on CPU or Disk HDD/SSD
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 30 Avg (IOU: 0.337394, GIOU: 0.321106), Class: 0.225424, Obj: 0.056014, No Obj: 0.000010, .5R: 0.500000, .75R: 0.000000, count: 2, class_loss = 0.061944, iou_loss = 0.006100, total_loss = 0.068044
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 37 Avg (IOU: 0.762182, GIOU: 0.751219), Class: 0.892650, Obj: 0.642233, No Obj: 0.000279, .5R: 0.930233, .75R: 0.627907, count: 43, class_loss = 0.272874, iou_loss = 4.819667, total_loss = 5.092541
#  total_bbox = 36203, rewritten_bbox = 0.002762 %
#
#  1170: 0.167901, 0.073992 avg loss, 0.002610 rate, 0.485483 seconds, 74880 images, 0.295956 hours left
# Loaded: 0.638947 seconds - performance bottleneck on CPU or Disk HDD/SSD
# ...

# %%
# !pwd
# %cd drive/My\ Drive/darknet
# !chmod 755 darknet
# !chmod 755 ts
# !./darknet detector test cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights -dont_show -ext_output < test.txt > result_tiny.txt
# Out:
# /content
# /content/drive/My Drive/darknet

# %%
# !./darknet detector demo cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights road_signs_short_version.mp4 -out_filename out_tiny.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.3 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.2 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.1 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.9 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:21.0 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.8 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.7 	 AVG_FPS:19.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.4 	 AVG_FPS:19.6
#
# ...

# %%
# check accuracy mAP@IoU=50 - final weights
# !./darknet detector map cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
# ...

# %%
# check accuracy mAP@IoU=75 - final weights
# !./darknet detector map cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
# ...

# %%
# !./darknet detector test cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights -ext_output zakopianka.png
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
#    8 route  2 7 	                           ->  104 x 104 x 128
# ...

# %%
# !./darknet detector test cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights zakopianka.png -thresh 0.1
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# %cd darknet
# !./darknet detector test cfg/ts_data.data yolov4-tiny_test.cfg yolov4-tiny_train_7000.weights -dont_show  /content/ts/00042.jpg -iou_thresh 0.75 -thresh 0.75
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/drive/My Drive/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...
