# %% [markdown]
# [link text](https://)#Go to My Drive directory

# %%
# %cd drive/My Drive
# Out:
# /content/drive/My Drive

# %% [markdown]
# #Cloning and Building Darknet

# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14358, done.
# remote: Total 14358 (delta 0), reused 0 (delta 0), pack-reused 14358
# Receiving objects: 100% (14358/14358), 13.06 MiB | 8.39 MiB/s, done.
# Resolving deltas: 100% (9761/9761), done.
# Checking out files: 100% (2017/2017), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/drive/My Drive/darknet

# %%
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# make darknet (build)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd ..
# %cd darknet
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/darknet

# %%
import  os, sys
os.symlink('/content/drive/My Drive/ts', '/content/ts')
sys.path.insert(0, 'content/MyDrive')

# %%
# !./darknet detector train cfg/ts_data.data cfg/yolov3_ts_train.cfg weights/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.811760, GIOU: 0.809739), Class: 0.999942, Obj: 0.999154, No Obj: 0.000248, .5R: 1.000000, .75R: 1.000000, count: 2, class_loss = 0.000004, iou_loss = 0.072328, total_loss = 0.072333
#  total_bbox = 489953, rewritten_bbox = 0.146749 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000001, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000001, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...

# %% [markdown]
# #Continue trainnig with las saves weights

# %%
import  os, sys
os.symlink('/content/drive/My Drive/ts', '/content/ts')
sys.path.insert(0, 'content/MyDrive')

# %%
# !pwd
# %cd drive/My\ Drive/darknet
# !chmod 755 darknet
# !chmod 755 content/darknet/buckup/yolov3_ts_train_2000.weights
# Out:
# /content
# /content/drive/My Drive/darknet

# %%
# !./darknet detector train cfg/ts_data.data cfg/yolov3_ts_train.cfg yolov3_ts_train_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000003, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000002, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.685054, GIOU: 0.669604), Class: 0.978021, Obj: 0.996536, No Obj: 0.000176, .5R: 1.000000, .75R: 0.000000, count: 1, class_loss = 0.000671, iou_loss = 0.069011, total_loss = 0.069682
#  total_bbox = 142416, rewritten_bbox = 0.144647 %
# ...

# %% [markdown]
# #Running detector

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/darknet

# %%
# !pwd
# % cd drive/My\ Drive/darknet
# !chmod 755 darknet
# !chmod 755 ts
# !./darknet detector test cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights -dont_show -ext_output < test.txt > result_final.txt
# Out:
# /content/drive/My Drive/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
# check accuracy mAP@IoU=50
# !./darknet detector map cfg/ts_data.data cfg/yolov3_ts_train.cfg yolov3_ts_train_2000.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# check accuracy mAP@IoU=75
# !./darknet detector map cfg/ts_data.data cfg/yolov3_ts_train.cfg yolov3_ts_train_2000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# check accuracy mAP@IoU=50 - final weights
# !./darknet detector map cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# check accuracy mAP@IoU=50 - final weights
# !./darknet detector map cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detector demo cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights road_signs_short_version.mp4 -out_filename out_yolov3.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# FPS:24.9 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.6 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.7 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.5 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# danger: 30%
#
# FPS:25.1 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# other: 52%
#
# FPS:25.3 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:25.4 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# prohibitory: 35%
#
# FPS:25.2 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# other: 91%
#
# FPS:24.8 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# other: 89%
# prohibitory: 37%
#
# FPS:25.0 	 AVG_FPS:21.5
#
#  cvWriteFrame
# Objects:
#
# other: 85%
# ...

# %%
# !./darknet detector demo cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights road_signs_night_1.mp4 -out_filename out_night_yolov3.avi -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#
# prohibitory: 98%
#
# FPS:4.6 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
# prohibitory: 60%
#
# FPS:4.7 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
# prohibitory: 40%
#
# FPS:4.9 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
# prohibitory: 87%
#
# FPS:4.8 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
# danger: 28%
#
# FPS:4.9 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.7 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.6 	 AVG_FPS:4.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.4 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.5 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.5 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.4 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.3 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
# danger: 40%
#
# FPS:4.3 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.2 	 AVG_FPS:4.4
#
#  cvWriteFrame
# Objects:
#
# danger: 68%
#
# FPS:4.3 	 AVG_FPS:4.4
#
# ...

# %%
# %cd darknet
# !./darknet detector test cfg/ts_data.data cfg/yolov3_ts_test.cfg yolov3_ts_final.weights -dont_show  /content/ts/00042.jpg
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/drive/My Drive/darknet
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
